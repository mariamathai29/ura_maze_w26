# %% [markdown]
# ## Imports

# %%
# REINFORCE
# RL boosted decoder

# %%
import pickle
import random
from typing import List, Tuple
import numpy as np
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from maze import *

# %% [markdown]
# ## Setup

# %%
def load_samples(pkl_path: str, n_samples: int = 2000, seed: int = 0):
    with open(pkl_path, 'rb') as f:
        all_data = pickle.load(f)
    random.Random(seed).shuffle(all_data)
    picked = all_data[:n_samples]
    mazes = []
    lengths = []

    for maze, length in picked:
        arr = np.array(maze, dtype=np.float32)

        H, W = arr.shape
        newH = H + 1
        newW = W + 1
        padded = np.zeros((newH, newW), dtype=np.float32)
        padded[:H, :W] = arr

        mazes.append(padded)
        lengths.append(float(length))

    return mazes, lengths

# %%
class MazeDataset(Dataset):
    def __init__(self, mazes: List[np.ndarray], lengths: List[float]):
        assert len(mazes) == len(lengths)
        self.mazes = mazes
        self.lengths = lengths
        self.n = len(mazes)
        # assume all mazes same shape
        self.h, self.w = mazes[0].shape


    def __len__(self):
        return self.n


    def __getitem__(self, idx):
        maze = self.mazes[idx]
        length = self.lengths[idx]
        # normalize length to float32 and scale roughly to [0,1]
        return torch.from_numpy(maze).unsqueeze(0), torch.tensor(length, dtype=torch.float32)

# %% [markdown]
# ## Conditional Variational Autoencoder

# %%
F = torch.nn.functional

class ConvEncoder(nn.Module):
    def __init__(self, latent_dim=64, in_size=(20,20)):
        super().__init__()
        # assume input H,W divisible by 4 (20x20 common). adjust if needed.
        self.conv1 = nn.Conv2d(1, 32, 4, 2, 1)   # H/2
        self.conv2 = nn.Conv2d(32, 64, 4, 2, 1)  # H/4
        self.conv3 = nn.Conv2d(64, 128, 3, 1, 1)
        H, W = in_size
        feat_h = H // 4
        feat_w = W // 4
        
        self._flat = 128 * feat_h * feat_w
        self.fc_mu = nn.Linear(self._flat, latent_dim)
        self.fc_logvar = nn.Linear(self._flat, latent_dim)
        self.act = nn.GELU()

    def forward(self, x):
        x = self.act(self.conv1(x))
        x = self.act(self.conv2(x))
        x = self.act(self.conv3(x))
        x = x.view(x.size(0), -1)
        mu = self.fc_mu(x)
        logvar = self.fc_logvar(x)
        return mu, logvar

class ConvDecoder(nn.Module):
    def __init__(self, latent_dim=64, len_emb_dim=16, out_size=(20,20)):
        super().__init__()
        H, W = out_size
        feat_h = H // 4
        feat_w = W // 4
        self.fc = nn.Linear(latent_dim + len_emb_dim, 128 * feat_h * feat_w)
        self.act = nn.GELU()
        self.deconv1 = nn.ConvTranspose2d(128, 64, 4, 2, 1)  # *2
        self.deconv2 = nn.ConvTranspose2d(64, 32, 4, 2, 1)   # *2
        self.outc = nn.Conv2d(32, 1, 3, 1, 1)
    def forward(self, zc, H, W):
        h = self.fc(zc)
        feat_h = H // 4
        feat_w = W // 4
        h = h.view(h.size(0), 128, feat_h, feat_w)
        h = self.act(h)
        h = self.act(self.deconv1(h))
        h = self.act(self.deconv2(h))
        logits = self.outc(h)
        return logits

# %%
class ConditionalVAE(nn.Module):
    def __init__(self, latent_dim=64, len_emb_dim=16, in_size=(20,20)):
        super().__init__()
        self.enc = ConvEncoder(latent_dim=latent_dim, in_size=in_size)
        self.len_embed = nn.Sequential(nn.Linear(1, len_emb_dim), nn.GELU(), nn.Linear(len_emb_dim, len_emb_dim))
        self.dec = ConvDecoder(latent_dim=latent_dim, len_emb_dim=len_emb_dim, out_size=in_size)
        self.latent_dim = latent_dim
        self.in_size = in_size

    def reparam(self, mu, logvar):
        std = (0.5 * logvar).exp()
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x, length):
        mu, logvar = self.enc(x)
        z = self.reparam(mu, logvar)
        le = self.len_embed(length.unsqueeze(1))
        zc = torch.cat([z, le], dim=1)
        logits = self.dec(zc, *self.in_size)
        return logits, mu, logvar

    def generate(self, length, n=1, device='cpu'):
        self.to(device)
        self.eval()
        with torch.no_grad():
            z = torch.randn(n, self.latent_dim, device=device)
            le = torch.tensor([length]*n, dtype=torch.float32, device=device).unsqueeze(1)
            le = self.len_embed(le)
            zc = torch.cat([z, le], dim=1)
            logits = self.dec(zc, *self.in_size)
            probs = torch.sigmoid(logits)
            return (probs > 0.5).long().cpu().numpy().squeeze(1)

# %%
def kld_loss(mu, logvar):
    return -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())

def train_cvae(pkl_path='mazes.pkl', n_samples=2000, batch_size=64, epochs=20, lr=1e-3, latent_dim=64, device='mps'):
    mazes, lengths = load_samples(pkl_path, n_samples=n_samples)
    # infer input size from first sample
    H, W = mazes[0].shape
    ds = MazeDataset(mazes, lengths)
    dl = DataLoader(ds, batch_size=batch_size, shuffle=True, drop_last=True)

    model = ConditionalVAE(latent_dim=latent_dim, len_emb_dim=16, in_size=(H,W)).to(device)
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    bce = nn.BCEWithLogitsLoss()
    beta = 1e-3

    recon_hist = []
    kld_hist = []
    for epoch in range(1, epochs+1):
        model.train()
        running_r = 0.0
        running_k = 0.0
        for xb, lengths in dl:
            xb = xb.to(device)
            lengths = lengths.to(device)
            opt.zero_grad()
            logits, mu, logvar = model(xb, lengths)
            loss_recon = bce(logits, xb)
            loss_kld = kld_loss(mu, logvar)
            loss = loss_recon + beta * loss_kld
            loss.backward()
            opt.step()
            running_r += loss_recon.item()
            running_k += loss_kld.item()
        avg_r = running_r / len(dl)
        avg_k = running_k / len(dl)
        recon_hist.append(avg_r); kld_hist.append(avg_k)
        print(f"Epoch {epoch}: recon={avg_r:.4f} kld={avg_k:.6f} total={(avg_r+beta*avg_k):.4f}")
    # final loss plot
    plt.figure(); plt.plot(recon_hist,label='recon'); plt.plot(kld_hist,label='kld'); plt.legend(); plt.show()
    return model

# %%
def f(maze: list[list[int]], start: tuple = (0, 0), end: tuple | None = None) -> int:
    return 1 if path_len(maze, start, end) != -1 else 0

# NEW ADDED FUNCTION AND WRAPPER
def path_len(maze: list[list[int]], start: tuple = (0, 0), end: tuple | None = None) -> int:
    if end is None:
        end = (len(maze) - 1, len(maze[0]) - 1)
    startx, starty = start
    endx, endy = end
    if maze[startx][starty] == 1 or maze[endx][endy] == 1:
        return -1
    r, c = len(maze), len(maze[0])
    visited = [[False for _ in range(c)] for _ in range(r)]
    visited[startx][starty] = True
    queue = deque()
    queue.append((startx, starty, 0))
    directions = [(0, 1), (1, 0), (0, -1), (-1, 0)]
    while queue:
        x, y, dist = queue.popleft()
        if (x, y) == (endx, endy):
            return dist
        for dx, dy in directions:
            nx, ny = x + dx, y + dy
            if 0 <= nx < r and 0 <= ny < c and not visited[nx][ny] and maze[nx][ny] == 0:
                visited[nx][ny] = True
                queue.append((nx, ny, dist + 1))
    return -1

# %%
import copy
import torch
import torch.nn.functional as F
import math

mazes, lengths_data = load_samples('dataset/solvable_data.pkl')


def sample_lengths_from_data(lengths, n, device):
    idx = torch.randint(0, len(lengths), (n,), device=device)
    return torch.tensor([lengths[i] for i in idx.tolist()], dtype=torch.float32, device=device)

def gaussian_reward(maze, L, sigma=2.0):
    actual = maze_path_length(maze)
    if actual == -1:
        return 0.0
    diff = actual - L
    return math.exp(-(diff * diff) / (2 * sigma * sigma))

def binary_reward(maze, L):
    actual = maze_path_length(maze)
    rd = 0;
    if actual != -1:
        rd+=0.5
    # reward changes
    if actual == L:
        rd+=1
    return rd
    
    
def sample_target_lengths(batch_size, device, low=36, high=55):
    return torch.randint(low, high + 1, (batch_size,), device=device).float()

def fine_tune_solvability_reinforce(
    model,
  #  f_solvable,                 # python function: np.array (H,W) {0,1} -> bool/int reward
    lengths_data=lengths_data,
    steps=3000,
    batch_size=1000,
    lr=1e-4,
    device="mps",
    reg_to_old=0.01,            # keep model close to old distribution (stability)
    entropy_bonus=0.001,        # encourage exploration early
):
    model = model.to(device)
    model.train()

    # Freeze a reference copy to prevent collapse (optional but very helpful)
    old = copy.deepcopy(model).to(device).eval()
    for p in old.parameters():
        p.requires_grad_(False)

    opt = torch.optim.Adam(model.parameters(), lr=lr)

    # running baseline to reduce variance
    baseline = 0.0 # running baseline of recent solve rates
    baseline_momentum = 0.95

    H, W = model.in_size # maze dims

    for step in range(1, steps + 1):
        z = torch.randn(batch_size, model.latent_dim, device=device) # sample latent vector from normal distribution
        lengths = sample_target_lengths(batch_size, device)
        #lengths = sample_lengths_from_data(lengths_data, batch_size, device)
        # lengths = torch.zeros(batch_size, device=device) # since we don't care about generating a maze of a certain length i've just fed in zeroes for length.

        le = model.len_embed(lengths.unsqueeze(1)) # length embedding vector
        zc = torch.cat([z, le], dim=1) # concat vectors , decoder input

        logits = model.dec(zc, H, W)
        probs = torch.sigmoid(logits).clamp(1e-6, 1 - 1e-6)

        x = torch.bernoulli(probs)  # (B,1,H,W). convert probabilities (probs) to actual maze cell values
       # x = (probs > 0.5).float()
        
        # ---- reward from solver
        x_np = x.detach().cpu().numpy().astype("int32")[:, 0] # convert to format for maze solver
       # r_list = [1.0 if f_solvable(m) else 0.0 for m in x_np] # list of solvability 'scores' after running dfs solver on each maze in the batch.
        target_lengths = lengths.detach().cpu().numpy()
        r_list = [binary_reward(m, t) for m, t in zip(x_np, target_lengths)]
        r = torch.tensor(r_list, dtype=torch.float32, device=device)  # (B,)

        # ---- log probability of sampled mazes under current policy
        # log P(x) = sum_ij x*log p + (1-x)*log(1-p)
        logp = (x * torch.log(probs) + (1 - x) * torch.log(1 - probs)).sum(dim=(1,2,3))  # (B,)

        # ---- baseline + advantage
        r_mean = r.mean().item() # compute average reward across this batch
        baseline = baseline_momentum * baseline + (1 - baseline_momentum) * r_mean # compute running average
        adv = (r - baseline).detach() # better or worse than usual?

        # REINFORCE loss , minimize the negation
        # high advantage, high probability: good maze, model usually generates - good - large val
        # high advantage, low probability: good maze, not often generated
        # negative advantage - do not generate similarly in the future
        
        loss_pg = -(adv * logp).mean() 

        # ---- entropy : encourage exploration, uncertainty
        # H(Bernoulli(p)) = -p log p - (1-p) log(1-p)
        # compute entropy for every pixel across every maze in the batch, sums over all pixels, then averages over the batch
        # ent, how uncertain the model currently is on average
        ent = (-(probs * torch.log(probs) + (1 - probs) * torch.log(1 - probs))).sum(dim=(1,2,3)).mean()
        
        # try to maximize uncertainty within the bounds of the coeff
        loss_ent = -entropy_bonus * ent  # negative, maximize entropy

        with torch.no_grad():
            old_logits = old.dec(zc, H, W)
            old_probs = torch.sigmoid(old_logits).clamp(1e-6, 1 - 1e-6)

        # KL( Bern(p_old) || Bern(p_new) ) per pixel, summed
        # compare old probabilities vs new probabilities to the same vector, if there is a large difference, apply some penalty
        # penalty scaled by reg_to_old to avoid staying too close to original model results
        kl_pix = old_probs * (torch.log(old_probs) - torch.log(probs)) + (1 - old_probs) * (torch.log(1 - old_probs) - torch.log(1 - probs))
        loss_reg = reg_to_old * kl_pix.sum(dim=(1,2,3)).mean()

        # compute loss as addition of advantage, uncertainty, similarity to original
        loss = loss_pg + loss_ent + loss_reg

        opt.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        opt.step()

        if step % 50 == 0:
            solv_list = [1.0 if path_len(m) != -1 else 0.0 for m in x_np]
            solv_rate = float(np.mean(solv_list))
            print(f"step {step:5d}  reward={r_mean:.3f}  solv_rate={solv_rate:.3f}  baseline={baseline:.3f}  loss={loss.item():.3f}")
            #print(f"step {step:5d}  solv_rate={r_mean:.3f}  baseline={baseline:.3f}  loss={loss.item():.3f}")

    return model

# %%
loaded_model = torch.load('saved_models/base_model.pt')
loaded_model.eval()
# Out:
# ConditionalVAE(
#   (enc): ConvEncoder(
#     (conv1): Conv2d(1, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fc_mu): Linear(in_features=3200, out_features=64, bias=True)
#     (fc_logvar): Linear(in_features=3200, out_features=64, bias=True)
#     (act): GELU(approximate='none')
#   )
#   (len_embed): Sequential(
#     (0): Linear(in_features=1, out_features=16, bias=True)
#     (1): GELU(approximate='none')
#     (2): Linear(in_features=16, out_features=16, bias=True)
#   )
#   (dec): ConvDecoder(
#     (fc): Linear(in_features=80, out_features=3200, bias=True)
#     (act): GELU(approximate='none')
#     (deconv1): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (deconv2): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (outc): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
model = fine_tune_solvability_reinforce(
    loaded_model,
  #  f_solvable=f,
    steps=3000,
    batch_size=1000,
    lr=1e-4,
    device="mps",
)
# Out:
# step    50  reward=0.497  solv_rate=0.904  baseline=0.456  loss=1.610
# step   100  reward=0.520  solv_rate=0.930  baseline=0.506  loss=0.593
# step   150  reward=0.510  solv_rate=0.935  baseline=0.511  loss=0.186
# step   200  reward=0.502  solv_rate=0.921  baseline=0.512  loss=-0.279
# step   250  reward=0.516  solv_rate=0.925  baseline=0.517  loss=0.033
# step   300  reward=0.530  solv_rate=0.949  baseline=0.516  loss=0.780
# step   350  reward=0.526  solv_rate=0.959  baseline=0.519  loss=0.400
# step   400  reward=0.515  solv_rate=0.937  baseline=0.520  loss=-0.205
# step   450  reward=0.518  solv_rate=0.942  baseline=0.520  loss=-0.203
# step   500  reward=0.522  solv_rate=0.954  baseline=0.522  loss=-0.048
# step   550  reward=0.517  solv_rate=0.948  baseline=0.519  loss=-0.116
# step   600  reward=0.518  solv_rate=0.948  baseline=0.522  loss=-0.084
# step   650  reward=0.526  solv_rate=0.942  baseline=0.520  loss=0.204
# step   700  reward=0.531  solv_rate=0.956  baseline=0.518  loss=0.759
# step   750  reward=0.517  solv_rate=0.953  baseline=0.519  loss=0.047
# step   800  reward=0.519  solv_rate=0.954  baseline=0.522  loss=-0.170
# step   850  reward=0.513  solv_rate=0.938  baseline=0.523  loss=-0.309
# step   900  reward=0.516  solv_rate=0.943  baseline=0.517  loss=-0.135
# step   950  reward=0.527  solv_rate=0.950  baseline=0.520  loss=0.356
# step  1000  reward=0.507  solv_rate=0.941  baseline=0.521  loss=-0.740
# step  1050  reward=0.533  solv_rate=0.950  baseline=0.522  loss=0.678
# step  1100  reward=0.515  solv_rate=0.937  baseline=0.517  loss=-0.087
# step  1150  reward=0.524  solv_rate=0.936  baseline=0.521  loss=0.349
# step  1200  reward=0.518  solv_rate=0.945  baseline=0.520  loss=-0.078
# step  1250  reward=0.522  solv_rate=0.958  baseline=0.519  loss=0.435
# step  1300  reward=0.544  solv_rate=0.970  baseline=0.521  loss=1.296
# step  1350  reward=0.513  solv_rate=0.941  baseline=0.522  loss=-0.541
# step  1400  reward=0.530  solv_rate=0.951  baseline=0.521  loss=0.904
# step  1450  reward=0.517  solv_rate=0.956  baseline=0.524  loss=-0.358
# step  1500  reward=0.523  solv_rate=0.946  baseline=0.524  loss=0.044
# step  1550  reward=0.512  solv_rate=0.947  baseline=0.522  loss=-0.744
# step  1600  reward=0.525  solv_rate=0.935  baseline=0.522  loss=0.171
# step  1650  reward=0.516  solv_rate=0.943  baseline=0.523  loss=-0.428
# step  1700  reward=0.530  solv_rate=0.946  baseline=0.522  loss=0.241
# step  1750  reward=0.517  solv_rate=0.942  baseline=0.523  loss=-0.100
# step  1800  reward=0.530  solv_rate=0.954  baseline=0.521  loss=0.511
# step  1850  reward=0.527  solv_rate=0.944  baseline=0.522  loss=0.225
# step  1900  reward=0.521  solv_rate=0.962  baseline=0.524  loss=-0.003
# step  1950  reward=0.525  solv_rate=0.954  baseline=0.521  loss=-0.013
# step  2000  reward=0.536  solv_rate=0.957  baseline=0.519  loss=0.709
# step  2050  reward=0.516  solv_rate=0.941  baseline=0.522  loss=-0.403
# step  2100  reward=0.512  solv_rate=0.949  baseline=0.524  loss=-0.671
# step  2150  reward=0.525  solv_rate=0.957  baseline=0.521  loss=0.431
# step  2200  reward=0.512  solv_rate=0.937  baseline=0.519  loss=-0.271
# step  2250  reward=0.529  solv_rate=0.961  baseline=0.524  loss=0.445
# step  2300  reward=0.531  solv_rate=0.946  baseline=0.521  loss=0.860
# step  2350  reward=0.535  solv_rate=0.945  baseline=0.521  loss=1.183
# step  2400  reward=0.510  solv_rate=0.934  baseline=0.522  loss=-0.423
# step  2450  reward=0.508  solv_rate=0.936  baseline=0.522  loss=-0.892
# step  2500  reward=0.529  solv_rate=0.953  baseline=0.520  loss=0.506
# step  2550  reward=0.526  solv_rate=0.951  baseline=0.521  loss=0.610
# step  2600  reward=0.521  solv_rate=0.953  baseline=0.520  loss=0.109
# step  2650  reward=0.533  solv_rate=0.963  baseline=0.524  loss=0.272
# step  2700  reward=0.517  solv_rate=0.948  baseline=0.520  loss=-0.286
# step  2750  reward=0.521  solv_rate=0.953  baseline=0.522  loss=0.049
# step  2800  reward=0.521  solv_rate=0.943  baseline=0.521  loss=-0.003
# step  2850  reward=0.525  solv_rate=0.958  baseline=0.521  loss=0.386
# step  2900  reward=0.518  solv_rate=0.952  baseline=0.521  loss=-0.107
# step  2950  reward=0.533  solv_rate=0.959  baseline=0.522  loss=0.834
# step  3000  reward=0.527  solv_rate=0.950  baseline=0.522  loss=0.268

# %%
import torch
torch.save(model, "solvable_models/tier_base.pt")

# %%
loaded_model = torch.load('saved_models/3k_decoder.pt')
loaded_model.eval()
# Out:
# ConditionalVAE(
#   (enc): ConvEncoder(
#     (conv1): Conv2d(1, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fc_mu): Linear(in_features=3200, out_features=64, bias=True)
#     (fc_logvar): Linear(in_features=3200, out_features=64, bias=True)
#     (act): GELU(approximate='none')
#   )
#   (len_embed): Sequential(
#     (0): Linear(in_features=1, out_features=16, bias=True)
#     (1): GELU(approximate='none')
#     (2): Linear(in_features=16, out_features=16, bias=True)
#   )
#   (dec): ConvDecoder(
#     (fc): Linear(in_features=80, out_features=3200, bias=True)
#     (act): GELU(approximate='none')
#     (deconv1): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (deconv2): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (outc): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
model = fine_tune_solvability_reinforce(
    loaded_model,
  #  f_solvable=f,
    steps=3000,
    batch_size=1000,
    lr=1e-4,
    device="mps",
)
# Out:
# step    50  reward=0.504  solv_rate=0.921  baseline=0.449  loss=3.191
# step   100  reward=0.520  solv_rate=0.952  baseline=0.514  loss=0.143
# step   150  reward=0.535  solv_rate=0.964  baseline=0.527  loss=0.252
# step   200  reward=0.515  solv_rate=0.959  baseline=0.527  loss=-0.968
# step   250  reward=0.521  solv_rate=0.956  baseline=0.529  loss=-0.836
# step   300  reward=0.526  solv_rate=0.947  baseline=0.529  loss=-0.483
# step   350  reward=0.527  solv_rate=0.961  baseline=0.529  loss=0.136
# step   400  reward=0.526  solv_rate=0.971  baseline=0.530  loss=-0.323
# step   450  reward=0.530  solv_rate=0.961  baseline=0.529  loss=0.071
# step   500  reward=0.540  solv_rate=0.973  baseline=0.529  loss=0.525
# step   550  reward=0.535  solv_rate=0.961  baseline=0.530  loss=0.179
# step   600  reward=0.552  solv_rate=0.974  baseline=0.531  loss=1.352
# step   650  reward=0.520  solv_rate=0.953  baseline=0.528  loss=-0.517
# step   700  reward=0.525  solv_rate=0.965  baseline=0.530  loss=-0.934
# step   750  reward=0.526  solv_rate=0.956  baseline=0.531  loss=-0.430
# step   800  reward=0.526  solv_rate=0.973  baseline=0.531  loss=-0.471
# step   850  reward=0.531  solv_rate=0.962  baseline=0.529  loss=-0.059
# step   900  reward=0.532  solv_rate=0.966  baseline=0.533  loss=-0.173
# step   950  reward=0.525  solv_rate=0.965  baseline=0.530  loss=-0.762
# step  1000  reward=0.521  solv_rate=0.968  baseline=0.531  loss=-0.874
# step  1050  reward=0.541  solv_rate=0.973  baseline=0.531  loss=0.608
# step  1100  reward=0.544  solv_rate=0.971  baseline=0.529  loss=0.952
# step  1150  reward=0.524  solv_rate=0.960  baseline=0.528  loss=-0.445
# step  1200  reward=0.529  solv_rate=0.946  baseline=0.526  loss=-0.250
# step  1250  reward=0.522  solv_rate=0.966  baseline=0.529  loss=-0.688
# step  1300  reward=0.523  solv_rate=0.958  baseline=0.530  loss=-0.359
# step  1350  reward=0.518  solv_rate=0.957  baseline=0.528  loss=-0.919
# step  1400  reward=0.525  solv_rate=0.959  baseline=0.526  loss=-0.239
# step  1450  reward=0.535  solv_rate=0.959  baseline=0.531  loss=0.291
# step  1500  reward=0.529  solv_rate=0.962  baseline=0.530  loss=-0.563
# step  1550  reward=0.516  solv_rate=0.951  baseline=0.525  loss=-0.968
# step  1600  reward=0.518  solv_rate=0.965  baseline=0.526  loss=-1.002
# step  1650  reward=0.535  solv_rate=0.955  baseline=0.529  loss=0.141
# step  1700  reward=0.525  solv_rate=0.951  baseline=0.530  loss=-1.036
# step  1750  reward=0.504  solv_rate=0.948  baseline=0.527  loss=-2.073
# step  1800  reward=0.525  solv_rate=0.957  baseline=0.527  loss=-0.634
# step  1850  reward=0.534  solv_rate=0.958  baseline=0.531  loss=0.063
# step  1900  reward=0.512  solv_rate=0.955  baseline=0.529  loss=-1.428
# step  1950  reward=0.528  solv_rate=0.960  baseline=0.527  loss=-0.379
# step  2000  reward=0.529  solv_rate=0.966  baseline=0.526  loss=-0.085
# step  2050  reward=0.528  solv_rate=0.958  baseline=0.527  loss=-0.241
# step  2100  reward=0.532  solv_rate=0.962  baseline=0.530  loss=0.173
# step  2150  reward=0.529  solv_rate=0.958  baseline=0.528  loss=-0.085
# step  2200  reward=0.518  solv_rate=0.940  baseline=0.527  loss=-0.905
# step  2250  reward=0.533  solv_rate=0.971  baseline=0.529  loss=-0.125
# step  2300  reward=0.511  solv_rate=0.945  baseline=0.530  loss=-1.831
# step  2350  reward=0.543  solv_rate=0.963  baseline=0.529  loss=0.964
# step  2400  reward=0.526  solv_rate=0.948  baseline=0.528  loss=-0.586
# step  2450  reward=0.532  solv_rate=0.970  baseline=0.527  loss=0.246
# step  2500  reward=0.522  solv_rate=0.958  baseline=0.528  loss=-0.889
# step  2550  reward=0.520  solv_rate=0.960  baseline=0.524  loss=-0.653
# step  2600  reward=0.543  solv_rate=0.957  baseline=0.528  loss=0.743
# step  2650  reward=0.515  solv_rate=0.956  baseline=0.528  loss=-1.421
# step  2700  reward=0.527  solv_rate=0.957  baseline=0.528  loss=-0.433
# step  2750  reward=0.531  solv_rate=0.970  baseline=0.530  loss=-0.248
# step  2800  reward=0.529  solv_rate=0.943  baseline=0.527  loss=-0.404
# step  2850  reward=0.541  solv_rate=0.976  baseline=0.530  loss=0.802
# step  2900  reward=0.535  solv_rate=0.965  baseline=0.530  loss=-0.062
# step  2950  reward=0.520  solv_rate=0.966  baseline=0.528  loss=-0.965
# step  3000  reward=0.543  solv_rate=0.960  baseline=0.531  loss=0.784

# %%
import torch
torch.save(model, "solvable_models/tier_3k.pt")
